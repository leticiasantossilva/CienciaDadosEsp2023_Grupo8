# %% [markdown]
# # Testes de busca de páginas - Getter

# %% [markdown]
# ## Treinando o uso da biblioteca Requests
#
# Referência: [tutorial](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# Importação da biblioteca

import requests

# Tutorial - get webpage
r = requests.get('https://api.github.com/events')

print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
#  Tutorial - conteúdo da webpage

r = requests.get('https://api.github.com/events')
r.text    # Imprime o código fonte da página
# Out:
# '[{"id":"34042077558","type":"WatchEvent","actor":{"id":111009970,"login":"akpi816218","display_login":"akpi816218","gravatar_id":"","url":"https://api.github.com/users/akpi816218","avatar_url":"https://avatars.githubusercontent.com/u/111009970?"},"repo":{"id":655515393,"name":"CopilotKit/CopilotKit","url":"https://api.github.com/repos/CopilotKit/CopilotKit"},"payload":{"action":"started"},"public":true,"created_at":"2023-12-10T00:35:59Z"},{"id":"34042077546","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":506161166,"name":"spianmo/github-stats","url":"https://api.github.com/repos/spianmo/github-stats"},"payload":{"repository_id":506161166,"push_id":16211783609,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a54a6e25956e5c1e0e2573062a3b3f0ece99073b","before":"8f31d52b78f3dae4d2952f00c4ce3ff512a41b69","commits":[{"sha":"a54a6e25956e5c1e0e2573062a3b3f0ece99073b","author":{"email":"github-stats[bot]@jstrieb.github.io","name":"jstrieb/github-stats"},"message":"Update generated files","distinct":true,"url":"https://api.github.com/repos/spianmo/github-stats/commits/a54a6e25956e5c1e0e2573062a3b3f0ece99073b"}]},"public":true,"created_at":"2023-12-10T00:35:59Z"},{"id":"34042077549","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":578918655,"name":"rcoffie/QGIS-Hugo","url":"https://api.github.com/repos/rcoffie/QGIS-Hugo"},"payload":{"repository_id":578918655,"push_id":16211783610,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"d9fd4e506060b116313c21fe2ef512736441a29e","before":"cc0859111572ae1b4ea758780acce876f63c3215","commits":[{"sha":"d9fd4e506060b116313c21fe2ef512736441a29e","author":{"email":"rcoffie@users.noreply.github.com","name":"rcoffie"},"message":"Funders scraped and committed via a GitHub Action.","distinct":true,"url":"https://api.github.com/repos/rcoffie/QGIS-Hugo/commits/d9fd4e506060b116313c21fe2ef512736441a29e"}]},"public":true,"created_at":"2023-12-10T00:35:59Z"},{"id":"34042077541","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":725617712,"name":"alterem/auto-green","url":"https://api.github.com/repos/alterem/auto-green"},"payload":{"repository_id":725617712,"push_id":16211783602,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"5e9b3633278d01fbe6e59b84d157309ada48b941","before":"17ec8eae50173c49e43c2abdff6b704197c02178","commits":[{"sha":"5e9b3633278d01fbe6e59b84d157309ada48b941","author":{"email":"alterem520@gmail.com","name":"alterem"},"message":"a commit a day keeps your girlfriend away⬆","distinct":true,"url":"https://api.github.com/repos/alterem/auto-green/commits/5e9b3633278d01fbe6e59b84d157309ada48b941"}]},"public":true,"created_at":"2023-12-10T00:35:59Z"},{"id":"34042077532","type":"PushEvent","actor":{"id":94146702,"login":"OmarElsayd","display_login":"OmarElsayd","gravatar_id":"","url":"https://api.github.com/users/OmarElsayd","avatar_url":"https://avatars.githubusercontent.com/u/94146702?"},"repo":{"id":588611914,"name":"OmarElsayd/Lecture-Quiz-Software","url":"https://api.github.com/repos/OmarElsayd/Lecture-Quiz-Software"},"payload":{"repository_id":588611914,"push_id":16211783594,"size":33,"distinct_size":1,"ref":"refs/heads/main","head":"670a3a385ff99a33d13ebc2c01f5fb306eae25d9","before":"583e57736c3bb1c744f66dcaf44e52e70d065839","commits":[{"sha":"512a250b61ae41db3866c0541a3c95aa0740e0f8","author":{"email":"oelsayd@my.gcu.edu","name":"omar elsayd"},"mes ...

# %%
# Tutorial - Leitura de webpage em Java Script (JSON)


r = requests.get('https://api.github.com/events')

r.json()
# Out:
# [{'id': '34042077644',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 692954654,
#    'name': 'nwallace83/home-server-helm',
#    'url': 'https://api.github.com/repos/nwallace83/home-server-helm'},
#   'payload': {'repository_id': 692954654,
#    'push_id': 16211783674,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '1f6a267bc835b7382f5b90e59eaad2ef77669975',
#    'before': '8a6db8f9ad48f95bfdd734699d052272e4f754ae',
#    'commits': [{'sha': '1f6a267bc835b7382f5b90e59eaad2ef77669975',
#      'author': {'email': 'nwallace83@users.noreply.github.com',
#       'name': 'nwallace83'},
#      'message': 'Update index.yaml\n\nSigned-off-by: nwallace83 <nwallace83@users.noreply.github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nwallace83/home-server-helm/commits/1f6a267bc835b7382f5b90e59eaad2ef77669975'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077650',
#   'type': 'PushEvent',
#   'actor': {'id': 30515222,
#    'login': 'ChiesiMario',
#    'display_login': 'ChiesiMario',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ChiesiMario',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30515222?'},
#   'repo': {'id': 693679917,
#    'name': 'ChiesiMario/My_Rss_Feed',
#    'url': 'https://api.github.com/repos/ChiesiMario/My_Rss_Feed'},
#   'payload': {'repository_id': 693679917,
#    'push_id': 16211783680,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '18322c701a55f5e784fdf43bf4072e059771ce8d',
#    'before': '8c71a096a857ace324fdd6a0ee5299dae88e666b',
#    'commits': [{'sha': '18322c701a55f5e784fdf43bf4072e059771ce8d',
#      'author': {'email': '30515222+ChiesiMario@users.noreply.github.com',
#       'name': 'ChiesiMario'},
#      'message': 'Update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ChiesiMario/My_Rss_Feed/commits/18322c701a55f5e784fdf43bf4072e059771ce8d'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077645',
#   'type': 'GollumEvent',
#   'actor': {'id': 96653085,
#    'login': 'Daanieeel',
#    'display_login': 'Daanieeel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Daanieeel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96653085?'},
#   'repo': {'id': 717137831,
#    'name': 'Academi-fy/backend',
#    'url': 'https://api.github.com/repos/Academi-fy/backend'},
#   'payload': {'pages': [{'page_name': '_Sidebar',
#      'title': '_Sidebar',
#      'summary': None,
#      'action': 'edited',
#      'sha': 'c7b75956eabd40d7fc3fad3acb92440718c6934c',
#      'html_url': 'https://github.com/Academi-fy/backend/wiki/_Sidebar'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z',
#   'org': {'id': 150464922,
#    'login': 'Academi-fy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Academi-fy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/150464922?'}},
#  {'id': '34042077640',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 113280573,
#    'login': 'gitops-for-cloudnativedays[bot]',
#    'display_login': 'gitops-for-cloudnativedays',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gitops-for-cloudnativedays[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/113280573?'},
#   'repo': {'id': 325795159,
#    'name': 'cloudnativedaysjp/dreamkast-infra',
#    'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra'},
#   'payload': {'action': 'closed',
#    'number': 3056,
#    'pull_request': {'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/3056',
#     'id': 1637496003,
#     'node_id': 'PR_kwDOE2s9V85hmjTD',
#     'html_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra/pull/3056',
#     'diff_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra/pull/3056.diff',
#     'patch_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra/pull/3056.patch',
#     'issue_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/3056',
#     'number': 3056,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Automated PR (staging/dk-main)',
#     'user': {'login': 'gitops-for-cloudnativedays[bot]',
#      'id': 113280573,
#      'node_id': 'BOT_kgDOBsCGPQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D',
#      'html_url': 'https://github.com/apps/gitops-for-cloudnativedays',
#      'followers_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': '**this PR is automatically created & merged**',
#     'created_at': '2023-12-10T00:35:58Z',
#     'updated_at': '2023-12-10T00:36:00Z',
#     'closed_at': '2023-12-10T00:35:59Z',
#     'merged_at': '2023-12-10T00:35:59Z',
#     'merge_commit_sha': '85afd242628be07211a51a044efd8d8d5f8aa115',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/3056/commits',
#     'review_comments_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/3056/comments',
#     'review_comment_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/3056/comments',
#     'statuses_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/statuses/41bd449ed3698c58658b62bc015fb11319313cbb',
#     'head': {'label': 'cloudnativedaysjp:staging/dk-main',
#      'ref': 'staging/dk-main',
#      'sha': '41bd449ed3698c58658b62bc015fb11319313cbb',
#      'user': {'login': 'cloudnativedaysjp',
#       'id': 44778132,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0Nzc4MTMy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cloudnativedaysjp',
#       'html_url': 'https://github.com/cloudnativedaysjp',
#       'followers_url': 'https://api.github.com/users/cloudnativedaysjp/followers',
#       'following_url': 'https://api.github.com/users/cloudnativedaysjp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cloudnativedaysjp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cloudnativedaysjp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cloudnativedaysjp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cloudnativedaysjp/orgs',
#       'repos_url': 'https://api.github.com/users/cloudnativedaysjp/repos',
#       'events_url': 'https://api.github.com/users/cloudnativedaysjp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cloudnativedaysjp/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 325795159,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjU3OTUxNTk=',
#       'name': 'dreamkast-infra',
#       'full_name': 'cloudnativedaysjp/dreamkast-infra',
#       'private': False,
#       'owner': {'login': 'cloudnativedaysjp',
#        'id': 44778132,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0Nzc4MTMy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cloudnativedaysjp',
#        'html_url': 'https://github.com/cloudnativedaysjp',
#        'followers_url': 'https://api.github.com/users/cloudnativedaysjp/followers',
#        'following_url': 'https://api.github.com/users/cloudnativedaysjp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cloudnativedaysjp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cloudnativedaysjp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cloudnativedaysjp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cloudnativedaysjp/orgs',
#        'repos_url': 'https://api.github.com/users/cloudnativedaysjp/repos',
#        'events_url': 'https://api.github.com/users/cloudnativedaysjp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cloudnativedaysjp/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra',
#       'forks_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/forks',
#       'keys_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/teams',
#       'hooks_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/events',
#       'assignees_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/tags',
#       'blobs_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/languages',
#       'stargazers_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/subscription',
#       'commits_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/merges',
#       'archive_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/downloads',
#       'issues_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/deployments',
#       'created_at': '2020-12-31T12:24:14Z',
#       'updated_at': '2023-03-20T01:17:34Z',
#       'pushed_at': '2023-12-10T00:35:59Z',
#       'git_url': 'git://github.com/cloudnativedaysjp/dreamkast-infra.git',
#       'ssh_url': 'git@github.com:cloudnativedaysjp/dreamkast-infra.git',
#       'clone_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra.git',
#       'svn_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra',
#       'homepage': None,
#       'size': 6029,
#       'stargazers_count': 13,
#       'watchers_count': 13,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 33,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 4,
#       'open_issues': 33,
#       'watchers': 13,
#       'default_branch': 'main'}},
#     'base': {'label': 'cloudnativedaysjp:main',
#      'ref': 'main',
#      'sha': 'b01a460207513f3cbf5bae07d9e53e828be9c941',
#      'user': {'login': 'cloudnativedaysjp',
#       'id': 44778132,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0Nzc4MTMy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cloudnativedaysjp',
#       'html_url': 'https://github.com/cloudnativedaysjp',
#       'followers_url': 'https://api.github.com/users/cloudnativedaysjp/followers',
#       'following_url': 'https://api.github.com/users/cloudnativedaysjp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cloudnativedaysjp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cloudnativedaysjp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cloudnativedaysjp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cloudnativedaysjp/orgs',
#       'repos_url': 'https://api.github.com/users/cloudnativedaysjp/repos',
#       'events_url': 'https://api.github.com/users/cloudnativedaysjp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cloudnativedaysjp/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 325795159,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjU3OTUxNTk=',
#       'name': 'dreamkast-infra',
#       'full_name': 'cloudnativedaysjp/dreamkast-infra',
#       'private': False,
#       'owner': {'login': 'cloudnativedaysjp',
#        'id': 44778132,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0Nzc4MTMy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cloudnativedaysjp',
#        'html_url': 'https://github.com/cloudnativedaysjp',
#        'followers_url': 'https://api.github.com/users/cloudnativedaysjp/followers',
#        'following_url': 'https://api.github.com/users/cloudnativedaysjp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cloudnativedaysjp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cloudnativedaysjp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cloudnativedaysjp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cloudnativedaysjp/orgs',
#        'repos_url': 'https://api.github.com/users/cloudnativedaysjp/repos',
#        'events_url': 'https://api.github.com/users/cloudnativedaysjp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cloudnativedaysjp/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra',
#       'forks_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/forks',
#       'keys_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/teams',
#       'hooks_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/events',
#       'assignees_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/tags',
#       'blobs_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/languages',
#       'stargazers_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/subscription',
#       'commits_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/merges',
#       'archive_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/downloads',
#       'issues_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/deployments',
#       'created_at': '2020-12-31T12:24:14Z',
#       'updated_at': '2023-03-20T01:17:34Z',
#       'pushed_at': '2023-12-10T00:35:59Z',
#       'git_url': 'git://github.com/cloudnativedaysjp/dreamkast-infra.git',
#       'ssh_url': 'git@github.com:cloudnativedaysjp/dreamkast-infra.git',
#       'clone_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra.git',
#       'svn_url': 'https://github.com/cloudnativedaysjp/dreamkast-infra',
#       'homepage': None,
#       'size': 6029,
#       'stargazers_count': 13,
#       'watchers_count': 13,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 33,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 4,
#       'open_issues': 33,
#       'watchers': 13,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/3056'},
#      'html': {'href': 'https://github.com/cloudnativedaysjp/dreamkast-infra/pull/3056'},
#      'issue': {'href': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/3056'},
#      'comments': {'href': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/issues/3056/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/3056/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/pulls/3056/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast-infra/statuses/41bd449ed3698c58658b62bc015fb11319313cbb'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'gitops-for-cloudnativedays[bot]',
#      'id': 113280573,
#      'node_id': 'BOT_kgDOBsCGPQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D',
#      'html_url': 'https://github.com/apps/gitops-for-cloudnativedays',
#      'followers_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gitops-for-cloudnativedays%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z',
#   'org': {'id': 44778132,
#    'login': 'cloudnativedaysjp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudnativedaysjp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?'}},
#  {'id': '34042077634',
#   'type': 'CreateEvent',
#   'actor': {'id': 78804757,
#    'login': 'k-dicken',
#    'display_login': 'k-dicken',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/k-dicken',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78804757?'},
#   'repo': {'id': 729669015,
#    'name': 'k-dicken/pixel-portfolio',
#    'url': 'https://api.github.com/repos/k-dicken/pixel-portfolio'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077649',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 553135518,
#    'name': 'igopereira1/igopereira1',
#    'url': 'https://api.github.com/repos/igopereira1/igopereira1'},
#   'payload': {'repository_id': 553135518,
#    'push_id': 16211783673,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '5f2b21bac4ba518d2de6dbf84dc916b0a64917ae',
#    'before': 'd1f5b5ff7cb265c3753ee38f5944b6e7d16c607d',
#    'commits': [{'sha': '5f2b21bac4ba518d2de6dbf84dc916b0a64917ae',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/igopereira1/igopereira1/commits/5f2b21bac4ba518d2de6dbf84dc916b0a64917ae'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077625',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 445741968,
#    'name': 'bishoppython/bishoppython',
#    'url': 'https://api.github.com/repos/bishoppython/bishoppython'},
#   'payload': {'repository_id': 445741968,
#    'push_id': 16211783661,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '5f2b21bac4ba518d2de6dbf84dc916b0a64917ae',
#    'before': '7da3d104805f2b162ee7218c67a74ed87af988b2',
#    'commits': [{'sha': '5f2b21bac4ba518d2de6dbf84dc916b0a64917ae',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bishoppython/bishoppython/commits/5f2b21bac4ba518d2de6dbf84dc916b0a64917ae'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077619',
#   'type': 'PushEvent',
#   'actor': {'id': 148840980,
#    'login': 'asiyegenc',
#    'display_login': 'asiyegenc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asiyegenc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/148840980?'},
#   'repo': {'id': 727002213,
#    'name': 'asiyegenc/TobetoJavaReactFullStackRentACarProjectWorkshop',
#    'url': 'https://api.github.com/repos/asiyegenc/TobetoJavaReactFullStackRentACarProjectWorkshop'},
#   'payload': {'repository_id': 727002213,
#    'push_id': 16211783657,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '74692bb5a99219cf2db506a44158da8c64725cf3',
#    'before': 'a95196485639433907b3e68089ba1ca86bb00ce8',
#    'commits': [{'sha': '74692bb5a99219cf2db506a44158da8c64725cf3',
#      'author': {'email': 'asiyeinangenc@gmail.com', 'name': 'asiyegenc'},
#      'message': 'Request and Response',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/asiyegenc/TobetoJavaReactFullStackRentACarProjectWorkshop/commits/74692bb5a99219cf2db506a44158da8c64725cf3'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077622',
#   'type': 'PushEvent',
#   'actor': {'id': 3746837,
#    'login': 'cameronjohnston',
#    'display_login': 'cameronjohnston',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cameronjohnston',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3746837?'},
#   'repo': {'id': 572739258,
#    'name': 'cameronjohnston/advent-of-code',
#    'url': 'https://api.github.com/repos/cameronjohnston/advent-of-code'},
#   'payload': {'repository_id': 572739258,
#    'push_id': 16211783660,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2b47dbb6bec40de40123876ee37d96cb5e2ddf4c',
#    'before': '73c535ad1ef8be195733567ec9cf59b03b70687d',
#    'commits': [{'sha': '2b47dbb6bec40de40123876ee37d96cb5e2ddf4c',
#      'author': {'email': 'cameron.johnston8@gmail.com',
#       'name': 'cameronjohnston'},
#      'message': 'Day 6 and 7. Day 7 was fun and quite satisfying that stuff like __gt__, sorting, get_type all worked as intended',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cameronjohnston/advent-of-code/commits/2b47dbb6bec40de40123876ee37d96cb5e2ddf4c'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077621',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 600400936,
#    'name': 'myesn/awesome',
#    'url': 'https://api.github.com/repos/myesn/awesome'},
#   'payload': {'repository_id': 600400936,
#    'push_id': 16211783662,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f027dd9c0c394c5f38788d50b12d593ac31c817f',
#    'before': '0f1a4c1a4607ae1fd4f31988f9ba50eaa8428006',
#    'commits': [{'sha': 'f027dd9c0c394c5f38788d50b12d593ac31c817f',
#      'author': {'email': 'myesn@foxmail.com', 'name': 'myesn'},
#      'message': 'chore(updates): updated entries in files',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/myesn/awesome/commits/f027dd9c0c394c5f38788d50b12d593ac31c817f'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077628',
#   'type': 'DeleteEvent',
#   'actor': {'id': 107187,
#    'login': 'takaishi',
#    'display_login': 'takaishi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/takaishi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107187?'},
#   'repo': {'id': 272451582,
#    'name': 'cloudnativedaysjp/dreamkast',
#    'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast'},
#   'payload': {'ref': 'update-community-lt-9',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z',
#   'org': {'id': 44778132,
#    'login': 'cloudnativedaysjp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudnativedaysjp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?'}},
#  {'id': '34042077617',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 35613825,
#    'login': 'vercel[bot]',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vercel[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#   'repo': {'id': 642130658,
#    'name': 'jibrilosman/portfolio-router',
#    'url': 'https://api.github.com/repos/jibrilosman/portfolio-router'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/jibrilosman/portfolio-router/comments/134616890',
#     'html_url': 'https://github.com/jibrilosman/portfolio-router/commit/9c95df39b6607ea77ba2e7c6c686187dfb6e0a10#commitcomment-134616890',
#     'id': 134616890,
#     'node_id': 'CC_kwDOJkYi4s4IBhc6',
#     'user': {'login': 'vercel[bot]',
#      'id': 35613825,
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/8329?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D',
#      'html_url': 'https://github.com/apps/vercel',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': '9c95df39b6607ea77ba2e7c6c686187dfb6e0a10',
#     'created_at': '2023-12-10T00:35:59Z',
#     'updated_at': '2023-12-10T00:35:59Z',
#     'author_association': 'NONE',
#     'body': 'Successfully deployed to the following URLs:\n\n## portfolio-router – ./\n\n[www.jibrilomar.com](https://www.jibrilomar.com)  \n[portfolio-router-git-main-jibrilosman.vercel.app](https://portfolio-router-git-main-jibrilosman.vercel.app)  \n[portfolio-router-jibrilosman.vercel.app](https://portfolio-router-jibrilosman.vercel.app)  \n[portfolio-router-vert.vercel.app](https://portfolio-router-vert.vercel.app)  \n[jibrilomar.com](https://jibrilomar.com)',
#     'reactions': {'url': 'https://api.github.com/repos/jibrilosman/portfolio-router/comments/134616890/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0}}},
#   'public': True,
#   'created_at': '2023-12-10T00:35:59Z'},
#  {'id': '34042077613',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 435838236,
#    'name': 'leoarauj0/leoarauj0',
#    'url': 'https://api.github.com/repos/leoarauj0/leoarauj0'},
#   'payload': {'repository_id': 435838236,
#    'push_id': 16211783652,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '5f2b21bac4ba518d2de6dbf84dc916b0a64917ae',
#    'before': '94b7aeb803a44a5c034aaf2a754c3718233effc4',
#    'commits': [{'sha': '5f2b21bac4ba518d2de6dbf84dc916b0a64917ae',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/leoarauj0/leoarauj0/commits/5f2b21bac4ba518d2de6dbf84dc916b0a64917ae'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077610',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 293445177,
#    'name': 'maolin-sen/cri-o',
#    'url': 'https://api.github.com/repos/maolin-sen/cri-o'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/117',
#     'repository_url': 'https://api.github.com/repos/maolin-sen/cri-o',
#     'labels_url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/117/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/117/comments',
#     'events_url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/117/events',
#     'html_url': 'https://github.com/maolin-sen/cri-o/pull/117',
#     'id': 1984727078,
#     'node_id': 'PR_kwDOEX2eOc5e_KdC',
#     'number': 117,
#     'title': 'build(deps): bump github.com/onsi/gomega from 1.20.0 to 1.30.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 4621589284,
#       'node_id': 'LA_kwDOEX2eOc8AAAABE3fbJA',
#       'url': 'https://api.github.com/repos/maolin-sen/cri-o/labels/lifecycle/stale',
#       'name': 'lifecycle/stale',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2023-11-09T02:56:58Z',
#     'updated_at': '2023-12-10T00:36:00Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/maolin-sen/cri-o/pulls/117',
#      'html_url': 'https://github.com/maolin-sen/cri-o/pull/117',
#      'diff_url': 'https://github.com/maolin-sen/cri-o/pull/117.diff',
#      'patch_url': 'https://github.com/maolin-sen/cri-o/pull/117.patch',
#      'merged_at': None},
#     'body': 'Bumps [github.com/onsi/gomega](https://github.com/onsi/gomega) from 1.20.0 to 1.30.0.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/onsi/gomega/releases">github.com/onsi/gomega\'s releases</a>.</em></p>\n<blockquote>\n<h2>v1.30.0</h2>\n<h2>1.30.0</h2>\n<h3>Features</h3>\n<ul>\n<li>BeTrueBecause and BeFalseBecause allow for better failure messages [4da4c7f]</li>\n</ul>\n<h3>Maintenance</h3>\n<ul>\n<li>Bump actions/checkout from 3 to 4 (<a href="https://redirect.github.com/onsi/gomega/issues/694">#694</a>) [6ca6e97]</li>\n<li>doc: fix type on gleak go doc [f1b8343]</li>\n</ul>\n<h2>v1.29.0</h2>\n<h2>1.29.0</h2>\n<h3>Features</h3>\n<ul>\n<li>MatchError can now take an optional func(error) bool + description [2b39142]</li>\n</ul>\n<h2>v1.28.1</h2>\n<h2>1.28.1</h2>\n<h3>Maintenance</h3>\n<ul>\n<li>Bump github.com/onsi/ginkgo/v2 from 2.12.0 to 2.13.0 [635d196]</li>\n<li>Bump github.com/google/go-cmp from 0.5.9 to 0.6.0 [14f8859]</li>\n<li>Bump golang.org/x/net from 0.14.0 to 0.17.0 [d8a6508]</li>\n<li><a href="https://redirect.github.com/onsi/gomega/issues/703">#703</a> doc(matchers): HaveEach() doc comment updated [2705bdb]</li>\n<li>Minor typos (<a href="https://redirect.github.com/onsi/gomega/issues/699">#699</a>) [375648c]</li>\n</ul>\n<h2>v1.28.0</h2>\n<h2>1.28.0</h2>\n<h3>Features</h3>\n<ul>\n<li>Add VerifyHost handler to ghttp (<a href="https://redirect.github.com/onsi/gomega/issues/698">#698</a>) [0b03b36]</li>\n</ul>\n<h3>Fixes</h3>\n<ul>\n<li>Read Body for Newer Responses in HaveHTTPBodyMatcher (<a href="https://redirect.github.com/onsi/gomega/issues/686">#686</a>) [18d6673]</li>\n</ul>\n<h3>Maintenance</h3>\n<ul>\n<li>Bump github.com/onsi/ginkgo/v2 from 2.11.0 to 2.12.0 (<a href="https://redirect.github.com/onsi/gomega/issues/693">#693</a>) [55a33f3]</li>\n<li>Typo in matchers.go (<a href="https://redirect.github.com/onsi/gomega/issues/691">#691</a>) [de68e8f]</li>\n<li>Bump commonmarker from 0.23.9 to 0.23.10 in /docs (<a href="https://redirect.github.com/onsi/gomega/issues/690">#690</a>) [ab17f5e]</li>\n<li>chore: update test matrix for Go 1.21 (<a href="https://redirect.github.com/onsi/gomega/issues/689">#689</a>) [5069017]</li>\n<li>Bump golang.org/x/net from 0.12.0 to 0.14.0 (<a href="https://redirect.github.com/onsi/gomega/issues/688">#688</a>) [babe25f]</li>\n</ul>\n<h2>v1.27.10</h2>\n<h2>1.27.10</h2>\n<h3>Fixes</h3>\n<ul>\n<li>fix: go 1.21 adding goroutine ID to creator+location (<a href="https://redirect.github.com/onsi/gomega/issues/685">#685</a>) [bdc7803]</li>\n</ul>\n<h2>v1.27.9</h2>\n<h2>1.27.9</h2>\n<!-- raw HTML omitted -->\n</blockquote>\n<p>... (truncated)</p>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/onsi/gomega/blob/master/CHANGELOG.md">github.com/onsi/gomega\'s changelog</a>.</em></p>\n<blockquote>\n<h2>1.30.0</h2>\n<h3>Features</h3>\n<ul>\n<li>BeTrueBecause and BeFalseBecause allow for better failure messages [4da4c7f]</li>\n</ul>\n<h3>Maintenance</h3>\n<ul>\n<li>Bump actions/checkout from 3 to 4 (<a href="https://redirect.github.com/onsi/gomega/issues/694">#694</a>) [6ca6e97]</li>\n<li>doc: fix type on gleak go doc [f1b8343]</li>\n</ul>\n<h2>1.29.0</h2>\n<h3>Features</h3>\n<ul>\n<li>MatchError can now take an optional func(error) bool + description [2b39142]</li>\n</ul>\n<h2>1.28.1</h2>\n<h3>Maintenance</h3>\n<ul>\n<li>Bump github.com/onsi/ginkgo/v2 from 2.12.0 to 2.13.0 [635d196]</li>\n<li>Bump github.com/google/go-cmp from 0.5.9 to 0.6.0 [14f8859]</li>\n<li>Bump golang.org/x/net from 0.14.0 to 0.17.0 [d8a6508]</li>\n<li><a href="https://redirect.github.com/onsi/gomega/issues/703">#703</a> doc(matchers): HaveEach() doc comment updated [2705bdb]</li>\n<li>Minor typos (<a href="https://redirect.github.com/onsi/gomega/issues/699">#699</a>) [375648c]</li>\n</ul>\n<h2>1.28.0</h2>\n<h3>Features</h3>\n<ul>\n<li>Add VerifyHost handler to ghttp (<a href="https://redirect.github.com/onsi/g ...
#     'reactions': {'url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/117/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/117/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/comments/1848796281',
#     'html_url': 'https://github.com/maolin-sen/cri-o/pull/117#issuecomment-1848796281',
#     'issue_url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/117',
#     'id': 1848796281,
#     'node_id': 'IC_kwDOEX2eOc5uMmR5',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2023-12-10T00:35:59Z',
#     'updated_at': '2023-12-10T00:35:59Z',
#     'author_association': 'NONE',
#     'body': 'A friendly reminder that this PR had no activity for 30 days.',
#     'reactions': {'url': 'https://api.github.com/repos/maolin-sen/cri-o/issues/comments/1848796281/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 15368,
#      'slug': 'github-actions',
#      'node_id': 'MDM6QXBwMTUzNjg=',
#      'owner': {'login': 'github',
#       'id': 9919,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk5MTk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9919?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/github',
#       'html_url': 'https://github.com/github',
#       'followers_url': 'https://api.github.com/users/github/followers',
#       'following_url': 'https://api.github.com/users/github/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/github/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/github/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/github/subscriptions',
#       'organizations_url': 'https://api.github.com/users/github/orgs',
#       'repos_url': 'https://api.github.com/users/github/repos',
#       'events_url': 'https://api.github.com/users/github/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/github/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'name': 'GitHub Actions',
#      'description': 'Automate your workflow from idea to production',
#      'external_url': 'https://help.github.com/en/actions',
#      'html_url': 'https://github.com/apps/github-actions',
#      'created_at': '2018-07-30T09:30:17Z',
#      'updated_at': '2019-12-10T19:04:12Z',
#      'permissions': {'actions': 'write',
#       'administration': 'read',
#       'checks': 'write',
#       'contents': 'write',
#       'deployments': 'write',
#       'discussions': 'write',
#       'issues': 'write',
#       'merge_queues': 'write',
#       'metadata': 'read',
#       'packages': 'write',
#       'pages': 'write',
#       'pull_requests': 'write',
#       'repository_hooks': 'write',
#       'repository_projects': 'write',
#       'security_events': 'write',
# ...
#       'git_commits_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/merges',
#       'archive_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/downloads',
#       'issues_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/deployments',
#       'created_at': '2023-10-06T06:55:20Z',
#       'updated_at': '2023-12-07T22:38:35Z',
#       'pushed_at': '2023-12-10T00:35:58Z',
#       'git_url': 'git://github.com/artificial-intelligence-department/ai_programming_playground.git',
#       'ssh_url': 'git@github.com:artificial-intelligence-department/ai_programming_playground.git',
#       'clone_url': 'https://github.com/artificial-intelligence-department/ai_programming_playground.git',
#       'svn_url': 'https://github.com/artificial-intelligence-department/ai_programming_playground',
#       'homepage': None,
#       'size': 1165706,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 23,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 22,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 23,
#       'open_issues': 22,
#       'watchers': 2,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/pulls/783'},
#      'html': {'href': 'https://github.com/artificial-intelligence-department/ai_programming_playground/pull/783'},
#      'issue': {'href': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/issues/783'},
#      'comments': {'href': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/issues/783/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/pulls/783/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/pulls/783/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/artificial-intelligence-department/ai_programming_playground/statuses/f42bbd389d73823f60005edfc5f1b2e1ffd3fe2a'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 473,
#     'deletions': 0,
#     'changed_files': 7}},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z',
#   'org': {'id': 147134944,
#    'login': 'artificial-intelligence-department',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/artificial-intelligence-department',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/147134944?'}},
#  {'id': '34042077598',
#   'type': 'PushEvent',
#   'actor': {'id': 40665208,
#    'login': 'Vladikasik',
#    'display_login': 'Vladikasik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Vladikasik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40665208?'},
#   'repo': {'id': 346160126,
#    'name': 'Vladikasik/statistic',
#    'url': 'https://api.github.com/repos/Vladikasik/statistic'},
#   'payload': {'repository_id': 346160126,
#    'push_id': 16211783647,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f8da8b9a47250eca79585a08da2aa5972fbcbe6e',
#    'before': 'e7d874f482abca1893e98560b9be63138dcbbfe1',
#    'commits': [{'sha': 'f8da8b9a47250eca79585a08da2aa5972fbcbe6e',
#      'author': {'email': 'vladislav.ainshtein@gmail.com',
#       'name': 'vladikasik'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Vladikasik/statistic/commits/f8da8b9a47250eca79585a08da2aa5972fbcbe6e'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077595',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 398627956,
#    'name': 'Sceleratis/Sceleratis',
#    'url': 'https://api.github.com/repos/Sceleratis/Sceleratis'},
#   'payload': {'repository_id': 398627956,
#    'push_id': 16211783641,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fac79550c35f8e2ba9355774d22e8c2dcf7daa12',
#    'before': 'eaa942027e9c729d21eb04c883be637597746511',
#    'commits': [{'sha': 'fac79550c35f8e2ba9355774d22e8c2dcf7daa12',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update Readme Image',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sceleratis/Sceleratis/commits/fac79550c35f8e2ba9355774d22e8c2dcf7daa12'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077593',
#   'type': 'PushEvent',
#   'actor': {'id': 147455344,
#    'login': 'waldosquiltion8',
#    'display_login': 'waldosquiltion8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/waldosquiltion8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/147455344?'},
#   'repo': {'id': 704903652,
#    'name': 'waldosquiltion8/randomCatFacts',
#    'url': 'https://api.github.com/repos/waldosquiltion8/randomCatFacts'},
#   'payload': {'repository_id': 704903652,
#    'push_id': 16211783648,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '109839942004862b2aefc94ae67ceee9e921e8ee',
#    'before': '5cf7397c6fd94755a13e06ca5fc56dff6763ea15',
#    'commits': [{'sha': '109839942004862b2aefc94ae67ceee9e921e8ee',
#      'author': {'email': '147455344+waldosquiltion8@users.noreply.github.com',
#       'name': 'waldosquiltion8'},
#      'message': 'Another great day with great cat fact',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/waldosquiltion8/randomCatFacts/commits/109839942004862b2aefc94ae67ceee9e921e8ee'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077583',
#   'type': 'PushEvent',
#   'actor': {'id': 1273463,
#    'login': 'johnfewell',
#    'display_login': 'johnfewell',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/johnfewell',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1273463?'},
#   'repo': {'id': 725765274,
#    'name': 'johnfewell/scrape',
#    'url': 'https://api.github.com/repos/johnfewell/scrape'},
#   'payload': {'repository_id': 725765274,
#    'push_id': 16211783638,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '15dc0e57dca8d8133b5c84c593ccb6c5e2c437e1',
#    'before': '328ae1eee30d15f9b28c485301e13ba04085f989',
#    'commits': [{'sha': '15dc0e57dca8d8133b5c84c593ccb6c5e2c437e1',
#      'author': {'email': 'fewell@gmail.com', 'name': 'John Fewell'},
#      'message': 'chore: update feed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/johnfewell/scrape/commits/15dc0e57dca8d8133b5c84c593ccb6c5e2c437e1'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077591',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 720755890,
#    'name': 'dontcrash/NRD',
#    'url': 'https://api.github.com/repos/dontcrash/NRD'},
#   'payload': {'repository_id': 720755890,
#    'push_id': 16211783637,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '80b497c2583e126e79b0845d80d3359c8418d800',
#    'before': 'c8167bbf87c461f63917671d4d2aa7320c0c891c',
#    'commits': [{'sha': '80b497c2583e126e79b0845d80d3359c8418d800',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'GitHub Actions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dontcrash/NRD/commits/80b497c2583e126e79b0845d80d3359c8418d800'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077578',
#   'type': 'CreateEvent',
#   'actor': {'id': 34386107,
#    'login': 'JAtoms',
#    'display_login': 'JAtoms',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JAtoms',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34386107?'},
#   'repo': {'id': 729669012,
#    'name': 'JAtoms/pdbe',
#    'url': 'https://api.github.com/repos/JAtoms/pdbe'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077572',
#   'type': 'PushEvent',
#   'actor': {'id': 107187,
#    'login': 'takaishi',
#    'display_login': 'takaishi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/takaishi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107187?'},
#   'repo': {'id': 272451582,
#    'name': 'cloudnativedaysjp/dreamkast',
#    'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast'},
#   'payload': {'repository_id': 272451582,
#    'push_id': 16211783626,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '60d60a085ecd4777a29f31b0845bf5db2fe49700',
#    'before': '660bb45debd9dbc48ed58339681745d936e8c7b4',
#    'commits': [{'sha': '6d4134e4b39cb4267e23956a3838cda375379c4c',
#      'author': {'email': 'jacopen@gmail.com', 'name': 'Kazuto Kusama'},
#      'message': 'Update community',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast/commits/6d4134e4b39cb4267e23956a3838cda375379c4c'},
#     {'sha': '60d60a085ecd4777a29f31b0845bf5db2fe49700',
#      'author': {'email': 'ryo.takaishi.0@gmail.com', 'name': 'Ryo Takaishi'},
#      'message': 'Merge pull request #2168 from cloudnativedaysjp/update-community-lt-9\n\nUpdate community',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cloudnativedaysjp/dreamkast/commits/60d60a085ecd4777a29f31b0845bf5db2fe49700'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z',
#   'org': {'id': 44778132,
#    'login': 'cloudnativedaysjp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudnativedaysjp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44778132?'}},
#  {'id': '34042077570',
#   'type': 'PushEvent',
#   'actor': {'id': 16705810,
#    'login': 'murat19',
#    'display_login': 'murat19',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/murat19',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16705810?'},
#   'repo': {'id': 693889317,
#    'name': 'murat19/Opencv',
#    'url': 'https://api.github.com/repos/murat19/Opencv'},
#   'payload': {'repository_id': 693889317,
#    'push_id': 16211783625,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/drawingImprovde',
#    'head': 'f60317bf6e5c2dbe241f07157edeff86046abf55',
#    'before': '0a66457b7cd2a7d6179efa2e2ad701407eea00a7',
#    'commits': [{'sha': 'f60317bf6e5c2dbe241f07157edeff86046abf55',
#      'author': {'email': 'murat.dedeoglu@oa.mo.gov', 'name': 'murat.dedeoglu'},
#      'message': 'tekbir sekil cizen',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/murat19/Opencv/commits/f60317bf6e5c2dbe241f07157edeff86046abf55'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:35:59Z'},
#  {'id': '34042077580',
#   'type': 'PushEvent',
#   'actor': {'id': 39115630,
#    'login': 'wnjoon',
#    'display_login': 'wnjoon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wnjoon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39115630?'},
#   'repo': {'id': 416313750,
#    'name': 'wnjoon/wnjoon.github.io',
#    'url': 'https://api.github.com/repos/wnjoon/wnjoon.github.io'},
#   'payload': {'repository_id': 416313750,
#    'push_id': 16211783633,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a36118b1bad216a70c9d04e9dea0602d6355137b',
#    'before': '2cdae8062359067cad638f56a6edf2a764de5fc3',
#    'commits': [{'sha': 'a36118b1bad216a70c9d04e9dea0602d6355137b',
#      'author': {'email': 'lwj@lgcns.com',
#       'name': '이원준 선임/Web3서비스팀'},
#      'message': 'Deploy 2023년 12월 10일 일요일 09시 35분 56초 KST',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wnjoon/wnjoon.github.io/commits/a36118b1bad216a70c9d04e9dea0602d6355137b'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'},
#  {'id': '34042077574',
#   'type': 'PushEvent',
#   'actor': {'id': 137921143,
#    'login': 'Abdalrahman-Alhamod',
#    'display_login': 'Abdalrahman-Alhamod',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Abdalrahman-Alhamod',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/137921143?'},
#   'repo': {'id': 729327494,
#    'name': 'Abdalrahman-Alhamod/Al-Aqsa-Mosque',
#    'url': 'https://api.github.com/repos/Abdalrahman-Alhamod/Al-Aqsa-Mosque'},
#   'payload': {'repository_id': 729327494,
#    'push_id': 16211783631,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '72652da4c65e4e4330436af12be1c94c2a3012e8',
#    'before': 'e77ca6d78d910b08ab3ef068a5d703e8af533d42',
#    'commits': [{'sha': '72652da4c65e4e4330436af12be1c94c2a3012e8',
#      'author': {'email': 'abd.alrahman.alhamod@gmail.com',
#       'name': 'Abdalrahman-Alhamod'},
#      'message': 'add new tree model',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Abdalrahman-Alhamod/Al-Aqsa-Mosque/commits/72652da4c65e4e4330436af12be1c94c2a3012e8'}]},
#   'public': True,
#   'created_at': '2023-12-10T00:36:00Z'}]

# %%
# Tutorial - Raw 

r = requests.get('https://api.github.com/events', stream=True)

r.raw

# %%
# Como salvar em file o que está em raw

with open('arquivo_test.txt', 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)

# %% [markdown]
# ### Abrindo arquivos no Python

# %%
#criar arquivo

arquivo2 = open('arquivo2.txt', 'w')
print(type(arquivo2))
arquivo2.close()
# Out:
# <class '_io.TextIOWrapper'>

# %%
#sintaxe que funcionou

with open('arquivo3.txt', 'w') as a3:
    a3.write('casa')
